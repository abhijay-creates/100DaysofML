# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.1.0-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Downloading lxml-6.1.0-cp312-cp312-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -------------------------- ------------- 2.6/4.0 MB 30.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 26.7 MB/s  0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-6.1.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 

webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers).text


soup=BeautifulSoup(webpage,'lxml')

# %%
soup.find_all('h1')[0].text.split()
# Out:
# ['Top', 'Companies', 'in', 'INDIA']

# %%
for i in soup.find_all('h2'):
  print(i.text.strip())
# Out:
# Companies in India
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# HCLTech
# ICICI Bank
# Tech Mahindra
# Genpact
# TP
# Jio
# Axis Bank
# Concentrix Corporation
# Amazon
# Reliance Retail
# iEnergizer
# LTIMindtree
# IBM
# Popular Collections by Industries
# Popular Collections by Cities
# Popular Collections by Roles

# %%
soup.find_all('path')[0]
# Out:
# <path d="M6.295 16L7.27 11.5632L4 8.57895L8.32 8.18421L10 4L11.68 8.18421L16 8.57895L12.73 11.5632L13.705 16L10 13.6474L6.295 16Z" fill="white"></path>

# %%
soup.find_all('div', class_="rating_star_container")[0].text.strip()
# Out:
# '3.3'
